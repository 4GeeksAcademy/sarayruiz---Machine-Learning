# %% [markdown]
# # EDA - Exploratory Data Analysis
#
# - [ ] 1. Definición del Problema
# - [ ] 2. Recopilación de Datos
# - [ ] 3. Análisis Descriptivo
# - [ ] 4. Limpieza de datos
#    - Eliminar Duplicados
#    - Eliminar información irrelevante
# - [ ] 5. Análisis de Variables
#    - [ ] Análisis de Variables Univariante
#            - Categóricas (histogramas)
#            - Numéricas (hist, boxplot, otros¿?)
#    - [ ] Análisis de Variables Multivariante
#            - Numéricas - Numéricas (regplot, heatmap(de la correlacion))
#            - Categórico - Categóricas (countplot)
#    - [ ] Numérico Categórico completo (heatmap sobre todas las correlaciones, pairplot)
# - [ ] 6. Ingeniería de características
#    - [ ] Outliers (Análisis descriptivo y visualización, decisiones)
#    - [ ] Faltantes (Análisis, decisiones)
#    - [ ] Inferencia de nuevas características (nuevas columnas)
# - [ ] 7. Split
#            - Dos enfoques
#            - train_test_split
# - [ ] 8. Scaling & Encoding
#     - [ ] Encoding
#            -  Label Encoding
#            -  One Hot Encoding
#            -  Ordinal Encoding
#     - [ ] Scaling
#            - Normalización
#            - MinMax
#     - [ ] (guardar scalers & encoders)
# - [ ] 9. Selección de Características
#
# # Machine Learning (Modelado)
#
# - [ ] Crear modelo - Probarlo  - Corregirlo (volver al punto 9 del EDA)
